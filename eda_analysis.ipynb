# %%
# %pip install pandas matplotlib
# Out:
# ...
#   Using cached pandas-3.0.6-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.11.2-cp314-cp314-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.4.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.65.0-cp314-cp314-win_amd64.whl.metadata (127 kB)
# ...
#   Using cached kiwisolver-1.5.1-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached pandas-3.0.6-cp314-cp314-win_amd64.whl (9.8 MB)
# Using cached matplotlib-3.11.2-cp314-cp314-win_amd64.whl (9.5 MB)
# Using cached contourpy-1.4.0-cp314-cp314-win_amd64.whl (240 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_music_dataset.csv")
df.head()
# Out:
#                                track_id       track_name artist_name  \
# 0  346d85e2-ffde-41b3-854a-589ed880b91f            Storm    Ethereal
# 1  12bc268a-363b-4f19-8fa8-0ced7ae1e462           Silent   The Wolfs
# 2  30d627d9-878d-4bb3-be59-71feb6ed4f3f  Shattered Lines     LolaOre
# 3  85501bb9-d221-4339-9e2e-29b1b3daff0a   Breaking Roses  Clay Black
# 4  7bf92bd2-c6fe-4869-a90e-242bb8bbe7a3            Lines   Knot Hart
#
#              album_name release_date  genre  duration_ms  popularity  \
# 0   The Hollow Journeys   06-10-2021    Pop       169594          47
# 1       Ancient Thunder   26-10-2024  K-Pop       256755          26
# 2       Twisted Harbors   12-11-2022   Punk       170212          46
# 3  The Blinding Letters   22-06-2020    Pop       181250           4
# 4    The Cosmic Letters   22-01-2024  Latin       160894          27
#
#    danceability  energy  ...  popularity_category  loudness_category  \
# ...

# %%
print("number of rows:",df.shape[0])
print("number of columns:",df.shape[1])
# Out:
# number of rows: 50000
# number of columns: 33

# %%
print("Column Name:")
for column in df.columns:
    print(column)
# Out:
# Column Name:
# track_id
# track_name
# artist_name
# album_name
# release_date
# genre
# duration_ms
# popularity
# danceability
# energy
# key
# loudness
# mode
# instrumentalness
# tempo
# stream_count
# country
# explicit
# label
# release_year
# release_month
# release_day_of_week
# duration_minutes
# popularity_category
# loudness_category
# key_name
# mode_name
# is_explicit_bool
# release_quarter
# is_weekend_release
# log_stream_count
# upbeat_score
# artist_track_count

# %%
df.info
# Out:
# <bound method DataFrame.info of                                    track_id       track_name  artist_name  \
# 0      346d85e2-ffde-41b3-854a-589ed880b91f            Storm     Ethereal
# 1      12bc268a-363b-4f19-8fa8-0ced7ae1e462           Silent    The Wolfs
# 2      30d627d9-878d-4bb3-be59-71feb6ed4f3f  Shattered Lines      LolaOre
# 3      85501bb9-d221-4339-9e2e-29b1b3daff0a   Breaking Roses   Clay Black
# 4      7bf92bd2-c6fe-4869-a90e-242bb8bbe7a3            Lines    Knot Hart
# ...                                     ...              ...          ...
# 49995  38913908-e3ab-42a2-9a97-2d1847c21e3b           Flames     Luna Ink
# 49996  83653402-ca85-4583-b7ec-13ab3e82888e             Love    Knot Hart
# 49997  4398dd33-ecfc-4c1a-ab9e-248f38082318        The Waves  Jasper Jade
# 49998  07c673e7-39a5-4c28-8789-163ae5f17f3f      Flying Eyes    ElaraRain
# 49999  888e233c-e7fd-4c0d-af8a-3cd98345a64e            Roads  Edge Brooks
#
# ...

# %%
df.describe()
# Out:
#          duration_ms    popularity  danceability        energy          key  \
# count   50000.000000  50000.000000  50000.000000  50000.000000  50000.00000
# mean   209814.455560     28.136820      0.661236      0.631853      5.47086
# std     44646.016547     15.999501      0.164143      0.168741      3.45610
# min     90000.000000      0.000000      0.000000      0.000000      0.00000
# 25%    179753.000000     16.000000      0.562400      0.523400      2.00000
# 50%    209689.000000     26.000000      0.675000      0.633400      5.00000
# 75%    239708.250000     39.000000      0.775400      0.744700      8.00000
# max    388117.000000     92.000000      1.000000      1.000000     11.00000
#
#            loudness          mode  instrumentalness         tempo  \
# count  50000.000000  50000.000000      50000.000000  50000.000000
# mean      -7.669547      0.650280          0.055166    119.067461
# std        2.621917      0.476886          0.095083     19.647807
# ...

# %%
## Missining Value Analysis

missing_values = df.isnull().sum()
print("Missing values in each columns:")
print(missing_values)
# Out:
# Missing values in each columns:
# track_id               0
# track_name             0
# artist_name            0
# album_name             0
# release_date           0
# genre                  0
# duration_ms            0
# popularity             0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# instrumentalness       0
# tempo                  0
# stream_count           0
# country                0
# explicit               0
# label                  0
# release_year           0
# release_month          0
# release_day_of_week    0
# duration_minutes       0
# popularity_category    0
# loudness_category      0
# key_name               0
# mode_name              0
# is_explicit_bool       0
# release_quarter        0
# is_weekend_release     0
# log_stream_count       0
# upbeat_score           0
# artist_track_count     0
# dtype: int64

# %%
## Duplicate Record Analysis

duplicate_count = df.duplicated().sum()
print("Number of duplicate rows: ",duplicate_count)
# Out:
# Number of duplicate rows:  0

# %%
## Genre Distributon

genre_counts = df["genre"].value_counts()
print(genre_counts)
# Out:
# genre
# R&B            13273
# Pop            12915
# Hip-Hop         3930
# Latin           2661
# EDM             2407
# Rock            2370
# Folk            2249
# Metal           1695
# K-Pop           1384
# Country         1294
# Indie           1065
# Trap             915
# Jazz             810
# Reggaeton        785
# Alternative      759
# Punk             384
# Classical        357
# Soul             325
# Afrobeats        224
# Disco            198
# Name: count, dtype: int64

# %%
genre_counts.head(10).plot(kind="bar", figsize=(10,6))
plt.title("Top 10 Genres by Number of Tracks")
plt.xlabel("Genre")
plt.ylabel("Number of Tracks")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
## Stream Count Analysis

print("Average streams: ",df["stream_count"].mean())
print("Median streams: ",df["stream_count"].median())
print("Minimum streams: ",df["stream_count"].min())
print("Maximum streams: ",df["stream_count"].max())
# Out:
# Average streams:  118378.92428
# Median streams:  15955.0
# Minimum streams:  100
# Maximum streams:  43345015

# %%
# Stream Distribution

plt.figure(figsize=(10,6))

plt.hist(df["stream_count"] ,bins=50)

plt.title("Distribution of Stream Counts")
plt.xlabel("Stream Count")
plt.xlabel("Number of Tracks")

plt.tight_layout()
plt.show()

# %%
# Top 10 Most Streamed Tracks

top_tracks = df.nlargest(10, "stream_count")
top_tracks[["track_name", "artist_name", "genre", "stream_count"]]
# Out:
#              track_name  artist_name        genre  stream_count
# 1528          The Roses   Grove Nova  Alternative      43345015
# 36998            Bitter  Flora Quinn         Rock      26635547
# 42813       The Streets     Ethereal          Pop      26314312
# 21643  Breaking Thunder    SethStone        Metal      20408155
# 49193         The Pages     IsleEyre          Pop      19265301
# 26622            Lights  Dean System      Hip-Hop      17238449
# 45015            Gentle    Rocco Ore          R&B      15776187
# 39012             Storm    Knot Hart          R&B      14545933
# 29091   Burning Islands     The Inks          Pop      14507867
# 13635       Broken Eyes   Prism Hart          R&B      14367106

# %%
## Release Year Analysis

year_counts = df["release_year"].value_counts().sort_index()
print(year_counts)
# Out:
# release_year
# 2020    8355
# 2021    8387
# 2022    8257
# 2023    8242
# 2024    8441
# 2025    8318
# Name: count, dtype: int64

# %%
year_counts.plot(kind="line", marker="o", figsize=(10,6))

plt.title("Number of Tracks Released by Year")
plt.xlabel("Release Year")
plt.ylabel("Number of Tracks")
plt.grid()
plt.tight_layout()
plt.show()

# %%
## Average Streams by Year

average_streams_year = df.groupby("release_year")["stream_count"].mean()
print(average_streams_year)
# Out:
# release_year
# 2020    114201.178815
# 2021    109909.482771
# 2022    111669.188931
# 2023    122437.959233
# 2024    126184.262765
# 2025    125832.774465
# Name: stream_count, dtype: float64

# %%
average_streams_year.plot(kind="line", marker="o", figsize=(10,6))
plt.title("Average Streams by Release Year")
plt.xlabel("Release Year")
plt.ylabel("Average Stream Count")
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Genre vs Average Streams

genre_streams = df.groupby("genre")["stream_count"].mean().sort_values(ascending=False)
print(genre_streams)
# Out:
# genre
# Alternative    170617.808959
# Disco          145136.414141
# Rock           132787.604641
# Jazz           130397.719753
# Country        129967.738022
# Latin          128065.534761
# Pop            127687.311189
# Metal          125242.965782
# Indie          123237.068545
# Afrobeats      121688.785714
# EDM            121486.703365
# Punk           114775.427083
# Hip-Hop        110965.376336
# K-Pop          110618.065751
# R&B            109868.284035
# Folk           101295.901289
# Reggaeton       92207.296815
# Trap            82298.898361
# Classical       79383.932773
# Soul            73054.036923
# Name: stream_count, dtype: float64

# %%
genre_streams.plot(kind="bar", figsize=(12,6))
plt.title("Average Streams by Genre")
plt.xlabel("Genre")
plt.ylabel("Average Stream Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
## Popularity Analysis

print(df["popularity"].describe())
# Out:
# count    50000.000000
# mean        28.136820
# std         15.999501
# min          0.000000
# 25%         16.000000
# 50%         26.000000
# 75%         39.000000
# max         92.000000
# Name: popularity, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.hist(df["popularity"], bins=20)
plt.title("Distribution of Music Popularity")
plt.xlabel("Popularity")
plt.ylabel("Number of Tracks")
plt.tight_layout()
plt.show()

# %%
# Popularity vs Streams

plt.figure(figsize=(10,6))
plt.scatter(
    df["popularity"],
    df["stream_count"],
    alpha=0.3
)
plt.title("Popularity vs Stream Count")
plt.xlabel("Popularity")
plt.ylabel("Stream Count")
plt.tight_layout()
plt.show()

# %%
correlation = df["popularity"].corr(df["stream_count"])
print("Correlation between popularity and stream count: ", correlation)
# Out:
# Correlation between popularity and stream count:  0.4001586404942141

# %%
# Audio Feature Analysis

audio_features =[
    "danceability",
    "energy",
    "instrumentalness",
    "tempo",
    "loudness",
    "upbeat_score"
]

df[audio_features].describe()
# Out:
#        danceability        energy  instrumentalness         tempo  \
# count  50000.000000  50000.000000      50000.000000  50000.000000
# mean       0.661236      0.631853          0.055166    119.067461
# std        0.164143      0.168741          0.095083     19.647807
# min        0.000000      0.000000          0.000000     60.000000
# 25%        0.562400      0.523400          0.010300    105.990000
# 50%        0.675000      0.633400          0.025700    118.575000
# 75%        0.775400      0.744700          0.057600    131.350000
# max        1.000000      1.000000          1.000000    220.000000
#
#            loudness  upbeat_score
# count  50000.000000  50000.000000
# mean      -7.669547      0.601615
# std        2.621917      0.105076
# min      -18.620000      0.057800
# 25%       -9.440000      0.542100
# 50%       -7.660000      0.606400
# 75%       -5.880000      0.671100
# max        0.000000      0.915400

# %%
## Audio features Correlation with Streams

correlation = df[
    audio_features + ["stream_count"]
].corr()["stream_count"].sort_values(ascending=False)
print(correlation)
# Out:
# stream_count        1.000000
# tempo               0.009106
# loudness            0.004579
# energy              0.004274
# upbeat_score        0.003258
# instrumentalness    0.002867
# danceability       -0.003071
# Name: stream_count, dtype: float64

# %%
## Explict Music Analysis

explicit_analysis = df.groupby("is_explicit_bool").agg(
    tracks=("track_id", "count"),
    average_streams=("stream_count", "mean"),
    average_popularity = ("popularity", "mean")
)
explicit_analysis
# Out:
#                   tracks  average_streams  average_popularity
# is_explicit_bool
# False              37576    119100.495130           28.174393
# True               12424    116196.555779           28.023181
